# %%
import pandas as pd
import json
pd.options.display.max_rows = 999
pd.options.display.max_columns = 100

# %%
with open('./json/1301_1332_1333-2011Q1-2013Q4.json') as json_file:
    data = json.load(json_file)

# %%
pd.DataFrame(list(data.values())[0])
# Out:
#    issued_share_num  treasury_stock_num  ex_net_sales  ex_operating_income  \
# 0       109282837.0                 NaN  1.770000e+11         3.300000e+09
# 1       109282837.0                 NaN  1.750000e+11         2.000000e+09
# 2       109282837.0                 NaN  1.880000e+11         3.100000e+09
# 3       109282837.0                 NaN  1.880000e+11         3.100000e+09
# 4       109282837.0                 NaN  1.750000e+11         2.000000e+09
# 5       109282837.0                 0.0  2.050000e+11         3.700000e+09
# 6       109282837.0                 NaN  1.770000e+11         3.300000e+09
# 7       109282837.0                 NaN  1.765000e+11         2.300000e+09
# 8       109282837.0                 NaN  1.850000e+11         3.200000e+09
# 9       109282837.0                 NaN  1.850000e+11         3.200000e+09
#
#    ex_ordinary_income  ex_net_income  ex_dividend  dividend  fiscal_year  \
# ...
